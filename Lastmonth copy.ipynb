# %%
import Portfolio
from Narrowing import knn 
from Narrowing import price
from DataColection import TickerPuller
import time

from Narrowing import adr
from Narrowing import volume

import imp
import mypytable
from Predicting import HiFinder 
import math
# Out:
# /tmp/ipykernel_127923/947520465.py:10: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp

# %%
user = Portfolio.portfolio()

user.cash=100

# %%
# recomended,day = knn.knn_past(days_back=22)

# %%
l = 30

while l > 19:
    # try:
        print("iteration")
        print(l)

        recomended,day = knn.knn_past(days_back=l)
        print("out of knn")
        inbudget,day = price.inbudget(recomended,user.cash,5,day=day)
        # from Narrowing import adr
        # from Narrowing import volume

        # print(len(inbudget))
        # print(len(day))
        good_volume,day = volume.remove_by_volume(inbudget,250000,250000,days=day)
        # print(len(good_volume))
        # print(len(day))


        stocks,day = adr.best_daily_range(good_volume,5,days=day)
        # print(len(stocks))
        # print(len(day))

        # print(stocks)

        # print(len(day))
        # print(day)
        stonks = []
        for val in stocks:
            # print(val)
            stonks.append(val.replace(".csv",""))
        for i ,stock in enumerate(stonks):
            TickerPuller.thisday(stock,int(day[i]))
            time.sleep(1.1)
        # print(day)
        # import imp
        # import mypytable
        # from Predicting import HiFinder 
        # import math
        # imp.reload(HiFinder)
        # imp.reload(Portfolio)
        money = user.cash
        amount_per_stock = money/5
        for name in stocks:
            mt = mypytable.MyPyTable()
            mt.load_from_file("Data/todays/"+name)
            
            past = HiFinder.StanderdStock(name)

            avg = past.Low_mean_std()[0]
            std = past.Low_mean_std()[1]
            print(avg,std)
            mockrun = mt.get_column('o')
            start = mockrun[0]
            mockrun.pop(0)
            for i,val in enumerate(mockrun):
                if (start - (avg - std)) >=val:
                    
                    user.liquid[name] = math.floor(amount_per_stock/val)
                    user.price[name] = val
                    user.cash = user.cash - (val * math.floor(amount_per_stock/val))
                    
                    break

            

        stonks = []
        for val in user.liquid.keys():
            print(val)
            stonks.append(val.replace(".csv",""))
        for i ,stock in enumerate(stonks):
            TickerPuller.thisday(stock,int(day[i] + 86400 ))
            time.sleep(1.1)

        for name in stocks:
            mt = mypytable.MyPyTable()
            mt.load_from_file("Data/todays/"+name)

            past = HiFinder.StanderdStock(name)

            avg = past.Hi_mean_std()[0]
            std = past.Hi_mean_std()[1]
            # print(avg,std)
            mockrun = mt.get_column('o')
            start = mockrun[0]
            mockrun.pop(0)
            for i,val in enumerate(mockrun):
                if (start + (avg + std)) <=val:
                    
                    user.cash = user.liquid[name] * val
                    user.profits +=  (user.liquid[name]*val) - (user.price[name]*user.liquid[name])

                    user.price[name] = 0
                    # user.cash = user.cash - (val * math.floor(amount_per_stock/val))
                    
                    break

                if i-1 == len(mockrun):
                    user.cash = user.liquid[name] * val
                    user.profits +=  (user.liquid[name]*val) - (user.price[name]*user.liquid[name])

                    user.price[name] = 0
                    # print("Here")
            
        # print(17.304999999999996)
        # print(0.41)
        # print(1.32)
        # print(0.40500000000000114)
        print("Profit")
        print(user.profits)
                    




            
            
            
            
            
            




        l-=1    
    # except:
    #     print("Bad run")
    #     print(l)
    #     l-=1
# Out:
# iteration
# 30
# out of knn
# [1659571200.0]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 21
#      16 good_volume,day = volume.remove_by_volume(inbudget,250000,250000,days=day)
#      17 # print(len(good_volume))
#      18 # print(len(day))
# ---> 21 stocks,day = adr.best_daily_range(good_volume,5,days=day)
#      22 # print(len(stocks))
#      23 # print(len(day))
#      24
#    (...)
#      27 # print(len(day))
#      28 # print(day)
#      29 stonks = []
#
# File ~/Documents/DataScience/StockTrader/Narrowing/adr.py:43, in best_daily_range(stocks, amount_of_stocks, days)
#      41 good =[]
#      42 for val in range(amount_of_stocks):
# ---> 43     good.append(stocks[avg[val][1]])
#      44     if days!= None:
#      45         days_out.append(avg[val][2])
#
# IndexError: list index out of range

# %%
# print(len(inbudget))
# print(len(recomended))

# %%
# from Narrowing import adr
# from Narrowing import volume

# print(len(inbudget))
# print(len(day))
# good_volume,day = volume.remove_by_volume(inbudget,250000,250000,days=day)
# print(len(good_volume))
# print(len(day))


# stocks,day = adr.best_daily_range(good_volume,5,days=day)
# print(len(stocks))
# print(len(day))

# print(stocks)

# print(len(day))
# print(day)
# stonks = []
# for val in stocks:
#     print(val)
#     stonks.append(val.replace(".csv",""))
# for i ,stock in enumerate(stonks):
#     TickerPuller.thisday(stock,int(day[i]))
#     time.sleep(1.1)
# print(day)
# import imp
# import mypytable
# from Predicting import HiFinder 
# import math
# imp.reload(HiFinder)
# imp.reload(Portfolio)
# money = user.cash
# amount_per_stock = money/5
# for name in stocks:
#     mt = mypytable.MyPyTable()
#     mt.load_from_file("Data/todays/"+name)
    
#     past = HiFinder.StanderdStock(name)

#     avg = past.Low_mean_std()[0]
#     std = past.Low_mean_std()[1]
#     # print(avg,std)
#     mockrun = mt.get_column('o')
#     start = mockrun[0]
#     mockrun.pop(0)
#     for i,val in enumerate(mockrun):
#         if (start - (avg - std)) >=val:
            
#             user.liquid[name] = math.floor(amount_per_stock/val)
#             user.price[name] = val
#             user.cash = user.cash - (val * math.floor(amount_per_stock/val))
            
#             break

    

# stonks = []
# for val in user.liquid.keys():
#     # print(val)
#     stonks.append(val.replace(".csv",""))
# for i ,stock in enumerate(stonks):
#     TickerPuller.thisday(stock,int(day[i] + 86400 ))
#     time.sleep(1.1)

# for name in stocks:
#     mt = mypytable.MyPyTable()
#     mt.load_from_file("Data/todays/"+name)

#     past = HiFinder.StanderdStock(name)

#     avg = past.Hi_mean_std()[0]
#     std = past.Hi_mean_std()[1]
#     # print(avg,std)
#     mockrun = mt.get_column('o')
#     start = mockrun[0]
#     mockrun.pop(0)
#     for i,val in enumerate(mockrun):
#         if (start + (avg + std)) <=val:
            
#             user.cash = user.liquid[name] * val
#             user.profits +=  (user.liquid[name]*val) - (user.price[name]*user.liquid[name])

#             user.price[name] = 0
#             # user.cash = user.cash - (val * math.floor(amount_per_stock/val))
            
#             break

#         if i-1 == len(mockrun):
#             user.cash = user.liquid[name] * val
#             user.profits +=  (user.liquid[name]*val) - (user.price[name]*user.liquid[name])

#             user.price[name] = 0
#             print("Here")
    
# print(17.304999999999996)
# print(0.41)
# print(1.32)
# print(0.40500000000000114)
# print(user.profits)

# %%
# print(len(day))
# print(day)
# stonks = []
# for val in stocks:
#     print(val)
#     stonks.append(val.replace(".csv",""))
# for i ,stock in enumerate(stonks):
#     TickerPuller.thisday(stock,int(day[i]))
#     time.sleep(1.1)
# print(day)
# import imp
# import mypytable
# from Predicting import HiFinder 
# import math
# imp.reload(HiFinder)
# imp.reload(Portfolio)
# money = user.cash
# amount_per_stock = money/5
# for name in stocks:
#     mt = mypytable.MyPyTable()
#     mt.load_from_file("Data/todays/"+name)
    
#     past = HiFinder.StanderdStock(name)

#     avg = past.Low_mean_std()[0]
#     std = past.Low_mean_std()[1]
#     # print(avg,std)
#     mockrun = mt.get_column('o')
#     start = mockrun[0]
#     mockrun.pop(0)
#     for i,val in enumerate(mockrun):
#         if (start - (avg - std)) >=val:
            
#             user.liquid[name] = math.floor(amount_per_stock/val)
#             user.price[name] = val
#             user.cash = user.cash - (val * math.floor(amount_per_stock/val))
            
#             break

    

# stonks = []
# for val in user.liquid.keys():
#     # print(val)
#     stonks.append(val.replace(".csv",""))
# for i ,stock in enumerate(stonks):
#     TickerPuller.thisday(stock,int(day[i] + 86400 ))
#     time.sleep(1.1)

# for name in stocks:
#     mt = mypytable.MyPyTable()
#     mt.load_from_file("Data/todays/"+name)

#     past = HiFinder.StanderdStock(name)

#     avg = past.Hi_mean_std()[0]
#     std = past.Hi_mean_std()[1]
#     # print(avg,std)
#     mockrun = mt.get_column('o')
#     start = mockrun[0]
#     mockrun.pop(0)
#     for i,val in enumerate(mockrun):
#         if (start + (avg + std)) <=val:
            
#             user.cash = user.liquid[name] * val
#             user.profits +=  (user.liquid[name]*val) - (user.price[name]*user.liquid[name])

#             user.price[name] = 0
#             # user.cash = user.cash - (val * math.floor(amount_per_stock/val))
            
#             break

#         if i-1 == len(mockrun):
#             user.cash = user.liquid[name] * val
#             user.profits +=  (user.liquid[name]*val) - (user.price[name]*user.liquid[name])

#             user.price[name] = 0
#             print("Here")
    
# print(17.304999999999996)
# print(0.41)
# print(1.32)
# print(0.40500000000000114)
# print(user.profits)

# %%
# import imp
# import mypytable
# from Predicting import HiFinder 
# import math
# imp.reload(HiFinder)
# imp.reload(Portfolio)
# money = user.cash
# amount_per_stock = money/5
# for name in stocks:
#     mt = mypytable.MyPyTable()
#     mt.load_from_file("Data/todays/"+name)
    
#     past = HiFinder.StanderdStock(name)

#     avg = past.Low_mean_std()[0]
#     std = past.Low_mean_std()[1]
#     # print(avg,std)
#     mockrun = mt.get_column('o')
#     start = mockrun[0]
#     mockrun.pop(0)
#     for i,val in enumerate(mockrun):
#         if (start - (avg - std)) >=val:
            
#             user.liquid[name] = math.floor(amount_per_stock/val)
#             user.price[name] = val
#             user.cash = user.cash - (val * math.floor(amount_per_stock/val))
            
#             break

    

# stonks = []
# for val in user.liquid.keys():
#     # print(val)
#     stonks.append(val.replace(".csv",""))
# for i ,stock in enumerate(stonks):
#     TickerPuller.thisday(stock,int(day[i] + 86400 ))
#     time.sleep(1.1)

# for name in stocks:
#     mt = mypytable.MyPyTable()
#     mt.load_from_file("Data/todays/"+name)

#     past = HiFinder.StanderdStock(name)

#     avg = past.Hi_mean_std()[0]
#     std = past.Hi_mean_std()[1]
#     # print(avg,std)
#     mockrun = mt.get_column('o')
#     start = mockrun[0]
#     mockrun.pop(0)
#     for i,val in enumerate(mockrun):
#         if (start + (avg + std)) <=val:
            
#             user.cash = user.liquid[name] * val
#             user.profits +=  (user.liquid[name]*val) - (user.price[name]*user.liquid[name])

#             user.price[name] = 0
#             # user.cash = user.cash - (val * math.floor(amount_per_stock/val))
            
#             break

#         if i-1 == len(mockrun):
#             user.cash = user.liquid[name] * val
#             user.profits +=  (user.liquid[name]*val) - (user.price[name]*user.liquid[name])

#             user.price[name] = 0
#             print("Here")
    
# print(17.304999999999996)
# print(0.41)
# print(1.32)
# print(0.40500000000000114)
# print(user.profits)

# %%
# stonks = []
# for val in user.liquid.keys():
#     # print(val)
#     stonks.append(val.replace(".csv",""))
# for i ,stock in enumerate(stonks):
#     TickerPuller.thisday(stock,int(day[i] + 86400 ))
#     time.sleep(1.1)

# for name in stocks:
#     mt = mypytable.MyPyTable()
#     mt.load_from_file("Data/todays/"+name)

#     past = HiFinder.StanderdStock(name)

#     avg = past.Hi_mean_std()[0]
#     std = past.Hi_mean_std()[1]
#     # print(avg,std)
#     mockrun = mt.get_column('o')
#     start = mockrun[0]
#     mockrun.pop(0)
#     for i,val in enumerate(mockrun):
#         if (start + (avg + std)) <=val:
            
#             user.cash = user.liquid[name] * val
#             user.profits +=  (user.liquid[name]*val) - (user.price[name]*user.liquid[name])

#             user.price[name] = 0
#             # user.cash = user.cash - (val * math.floor(amount_per_stock/val))
            
#             break

#         if i-1 == len(mockrun):
#             user.cash = user.liquid[name] * val
#             user.profits +=  (user.liquid[name]*val) - (user.price[name]*user.liquid[name])

#             user.price[name] = 0
#             print("Here")
    
# print(17.304999999999996)
# print(0.41)
# print(1.32)
# print(0.40500000000000114)
# print(user.profits)

# %%
# ### Selling 

# # for val in user.liquid.keys():
# #     print(val)
    

# # print(len(day))
# # print(day)
# # stonks = []
# # for val in user.liquid.keys():
# #     # print(val)
# #     stonks.append(val.replace(".csv",""))
# # for i ,stock in enumerate(stonks):
# #     TickerPuller.thisday(stock,int(day[i] + 86400 ))
# #     time.sleep(1.1)
# # print(day)


# for name in stocks:
#     mt = mypytable.MyPyTable()
#     mt.load_from_file("Data/todays/"+name)

#     past = HiFinder.StanderdStock(name)

#     avg = past.Hi_mean_std()[0]
#     std = past.Hi_mean_std()[1]
#     # print(avg,std)
#     mockrun = mt.get_column('o')
#     start = mockrun[0]
#     mockrun.pop(0)
#     for i,val in enumerate(mockrun):
#         if (start + (avg + std)) <=val:
            
#             user.cash = user.liquid[name] * val
#             user.profits +=  (user.liquid[name]*val) - (user.price[name]*user.liquid[name])

#             user.price[name] = 0
#             # user.cash = user.cash - (val * math.floor(amount_per_stock/val))
            
#             break

#         if i-1 == len(mockrun):
#             user.cash = user.liquid[name] * val
#             user.profits +=  (user.liquid[name]*val) - (user.price[name]*user.liquid[name])

#             user.price[name] = 0
#             print("Here")
    
# print(17.304999999999996)
# print(0.41)
# print(1.32)
# print(0.40500000000000114)
# print(user.profits)
