# %%
import Portfolio
from Narrowing import knn 
from Narrowing import price
from DataColection import TickerPuller
import time

from Narrowing import adr
from Narrowing import volume

import imp
import mypytable
from Predicting import HiFinder 
import math
# Out:
# /tmp/ipykernel_102453/947520465.py:10: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp

# %%
user = Portfolio.portfolio()

user.cash=100

# %%
# recomended,day = knn.knn_past(days_back=22)

# %%
l = 30

while l > 19:
    # try:
        print("iteration")
        print(l)

        recomended,day = knn.knn_past(days_back=l)
        
        print("out of knn")
        inbudget,day = price.inbudget(recomended,user.cash,5,day=day)
        # from Narrowing import adr
        # from Narrowing import volume

        # print(len(inbudget))
        # print(len(day))
        good_volume,day = volume.remove_by_volume(inbudget,250000,250000,days=day)
        # print(len(good_volume))
        # print(len(day))


        stocks,day = adr.best_daily_range(good_volume,5,days=day)
        # print(len(stocks))
        # print(len(day))

        # print(stocks)

        # print(len(day))
        # print(day)
        stonks = []
        for val in stocks:
            # print(val)
            stonks.append(val.replace(".csv",""))
        for i ,stock in enumerate(stonks):
            TickerPuller.thisday(stock,int(day[i]))
            time.sleep(1.1)
        # print(day)
        # import imp
        # import mypytable
        # from Predicting import HiFinder 
        # import math
        # imp.reload(HiFinder)
        # imp.reload(Portfolio)
        bought = []
        money = user.cash
        amount_per_stock = money/5
        for name in stocks:
            mt = mypytable.MyPyTable()
            mt.load_from_file("Data/todays/"+name)
            
            past = HiFinder.StanderdStock(name)

            avg = past.Low_mean_std()[0]
            std = past.Low_mean_std()[1]
            # print(avg,std)
            mockrun = mt.get_column('o')
            start = mockrun[0]
            mockrun.pop(0)
            for i,val in enumerate(mockrun):
                if (start - (avg - std)) >=val:
                    
                    user.liquid[name] = math.floor(amount_per_stock/val)
                    user.price[name] = val
                    user.cash = user.cash - (val * math.floor(amount_per_stock/val))

                    
                    bought.append(name)
                    
                    break
        
        print("Cash after buying:",end=" ")
        print(user.cash)

        print("keys:",end="")
        print(user.liquid.keys())

        stonks = []
        for val in user.liquid.keys():
            # print(val)
            stonks.append(val.replace(".csv",""))
        for i ,stock in enumerate(stonks):
            TickerPuller.thisday(stock,int(day[0] + 86400 ))
            time.sleep(1.1)
        print("Amount of stock:",end=" ")
        print(len(stocks))
        for name in bought:
            mt = mypytable.MyPyTable()
            mt.load_from_file("Data/todays/"+name)

            past = HiFinder.StanderdStock(name)

            avg = past.Hi_mean_std()[0]
            std = past.Hi_mean_std()[1]
            # print(avg,std)
            mockrun = mt.get_column('o')
            start = mockrun[0]
            mockrun.pop(0)
            for i,val in enumerate(mockrun):
                if (start + (avg + std)) <=val:
                    print("slling")
                    
                    user.cash += user.liquid[name] * val
                    print("this")
                    print((user.liquid[name]*val))
                    print((user.price[name]*user.liquid[name]))
                    print(user.price[name])
                    user.profits +=  (user.liquid[name]*val) - (user.price[name]*user.liquid[name])
                    # user.price.pop(name)
                    # user.cash = user.cash - (val * math.floor(amount_per_stock/val))
                    
                    break

                if i> len (mockrun)*.75 :
                    user.cash += user.liquid[name] * val
                    user.profits +=  (user.liquid[name]*val) - (user.price[name]*user.liquid[name])

                    # user.price.pop(name)
                    print("Here")
                    break
        user.liquid.clear()        
        l-=1    
        print("profits:",end=" ")
        print(user.profits)
        print("cash:",end=" ")
        print(user.cash)
# Out:
# iteration
# 30
# out of knn
# Day: 3
# Day: 3
# Day: 3
# Day: 3
# Day: 3
# Cash after buying: 28.779999999999998
# keys:dict_keys(['ALLO.csv', 'LPSN.csv', 'RDFN.csv', 'EQRX.csv', 'CD.csv'])
# Day: 4
# Day: 4
# Day: 4
# Day: 4
# Day: 4
# Amount of stock: 5
# Here
# Here
# slling
# this
# 12.33
# 11.0
# 11.0
# Here
# profits: -0.3450000000000024
# cash: 85.175
# iteration
# 29
# out of knn
# Day: 4
# Day: 4
# Day: 4
# Cash after buying: 41.30499999999999
# keys:dict_keys(['ALT.csv', 'FGEN.csv', 'CGC.csv'])
# Day: 5
# Day: 5
# Day: 5
# Amount of stock: 3
# slling
# this
# 14.94
# 12.67
# 12.67
# Here
# Here
# profits: 1.6749999999999972
# cash: 87.195
# iteration
# 28
# out of knn
# Day: 5
# Day: 2
# Day: 5
# Day: 5
# Day: 5
# Cash after buying: 14.694999999999999
# keys:dict_keys(['ALLO.csv', 'BLUE.csv', 'ABCL.csv', 'LYEL.csv', 'SFIX.csv'])
# Day: 6
# Day: 6
# Day: 6
# Day: 6
# Day: 6
# Amount of stock: 5
# Here
# Here
# Here
# slling
# this
# 15.1
# 14.22
# 7.11
# Here
# profits: 2.8499999999999925
# cash: 88.36999999999999
# iteration
# 27
# out of knn
# Day: 1
# Day: 1
# Day: 1
# Day: 1
# Day: 1
# Cash after buying: 17.679999999999996
# keys:dict_keys(['RXRX.csv', 'ULCC.csv', 'EQRX.csv', 'WW.csv', 'IMGN.csv'])
# Day: 2
# Day: 2
# Day: 2
# Day: 2
# Day: 2
# Amount of stock: 5
# Here
# Here
# Here
# Here
# profits: 5.054999999999993
# cash: 78.725
# iteration
# 26
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 8
#       5 print("iteration")
#       6 print(l)
# ----> 8 recomended,day = knn.knn_past(days_back=l)
#      10 print("out of knn")
#      11 inbudget,day = price.inbudget(recomended,user.cash,5,day=day)
#
# File ~/Documents/DataScience/StockTrader/Narrowing/knn.py:217, in knn_past(days_back)
#     214     Xlast.append(val[-1])
#     215 # print(X_test)
#     216 # print(len(X_test))
# --> 217 y_pred = knn.predict(X_test)
#     218 # print(y_pred)
#     219 # print("here")
#     220 correct = 0
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:234, in KNeighborsClassifier.predict(self, X)
#     218 """Predict the class labels for the provided data.
#     219
#     220 Parameters
#    (...)
#     229     Class labels for each data sample.
#     230 """
#     231 if self.weights == "uniform":
#     232     # In that case, we do not need the distances to perform
#     233     # the weighting so we do not compute them.
# --> 234     neigh_ind = self.kneighbors(X, return_distance=False)
#     235     neigh_dist = None
#     236 else:
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/neighbors/_base.py:861, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     858     else:
#     859         kwds = self.effective_metric_params_
# --> 861     chunked_results = list(
#     862         pairwise_distances_chunked(
#     863             X,
#     864             self._fit_X,
#     865             reduce_func=reduce_func,
#     866             metric=self.effective_metric_,
#     867             n_jobs=n_jobs,
#     868             **kwds,
#     869         )
#     870     )
#     872 elif self._fit_method in ["ball_tree", "kd_tree"]:
#     873     if issparse(X):
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/pairwise.py:1867, in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1865 else:
#    1866     X_chunk = X[sl]
# -> 1867 D_chunk = pairwise_distances(X_chunk, Y, metric=metric, n_jobs=n_jobs, **kwds)
#    1868 if (X is Y or Y is None) and PAIRWISE_DISTANCE_FUNCTIONS.get(
#    1869     metric, None
#    1870 ) is euclidean_distances:
#    1871     # zeroing diagonal, taking care of aliases of "euclidean",
#    1872     # i.e. "l2"
#    1873     D_chunk.flat[sl.start :: _num_samples(X) + 1] = 0
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/pairwise.py:2039, in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    2036         return distance.squareform(distance.pdist(X, metric=metric, **kwds))
#    2037     func = partial(distance.cdist, metric=metric, **kwds)
# -> 2039 return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/pairwise.py:1579, in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1576 X, Y, dtype = _return_float_dtype(X, Y)
#    1578 if effective_n_jobs(n_jobs) == 1:
# -> 1579     return func(X, Y, **kwds)
#    1581 # enforce a threading backend to prevent data communication overhead
#    1582 fd = delayed(_dist_wrapper)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/pairwise.py:300, in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     224 def euclidean_distances(
#     225     X, Y=None, *, Y_norm_squared=None, squared=False, X_norm_squared=None
#     226 ):
#     227     """
#     228     Compute the distance matrix between each pair from a vector array X and Y.
#     229
#    (...)
#     298            [1.41421356]])
#     299     """
# --> 300     X, Y = check_pairwise_arrays(X, Y)
#     302     if X_norm_squared is not None:
#     303         X_norm_squared = check_array(X_norm_squared, ensure_2d=False)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/pairwise.py:163, in check_pairwise_arrays(X, Y, precomputed, dtype, accept_sparse, force_all_finite, copy)
#     154 else:
#     155     X = check_array(
#     156         X,
#     157         accept_sparse=accept_sparse,
#    (...)
#     161         estimator=estimator,
#     162     )
# --> 163     Y = check_array(
#     164         Y,
#     165         accept_sparse=accept_sparse,
#     166         dtype=dtype,
#     167         copy=copy,
#     168         force_all_finite=force_all_finite,
#     169         estimator=estimator,
#     170     )
#     172 if precomputed:
#     173     if X.shape[1] != Y.shape[0]:
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/validation.py:879, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877         array = xp.astype(array, dtype, copy=False)
#     878     else:
# --> 879         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     880 except ComplexWarning as complex_warning:
#     881     raise ValueError(
#     882         "Complex data not supported\n{}\n".format(array)
#     883     ) from complex_warning
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_array_api.py:185, in _asarray_with_order(array, dtype, order, copy, xp)
#     182     xp, _ = get_namespace(array)
#     183 if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184     # Use NumPy API to support order
# --> 185     array = numpy.asarray(array, order=order, dtype=dtype)
#     186     return xp.asarray(array, copy=copy)
#     187 else:
#
# KeyboardInterrupt:

# %%
# print(len(inbudget))
# print(len(recomended))

# %%
# from Narrowing import adr
# from Narrowing import volume

# print(len(inbudget))
# print(len(day))
# good_volume,day = volume.remove_by_volume(inbudget,250000,250000,days=day)
# print(len(good_volume))
# print(len(day))


# stocks,day = adr.best_daily_range(good_volume,5,days=day)
# print(len(stocks))
# print(len(day))

# print(stocks)

# print(len(day))
# print(day)
# stonks = []
# for val in stocks:
#     print(val)
#     stonks.append(val.replace(".csv",""))
# for i ,stock in enumerate(stonks):
#     TickerPuller.thisday(stock,int(day[i]))
#     time.sleep(1.1)
# print(day)
# import imp
# import mypytable
# from Predicting import HiFinder 
# import math
# imp.reload(HiFinder)
# imp.reload(Portfolio)
# money = user.cash
# amount_per_stock = money/5
# for name in stocks:
#     mt = mypytable.MyPyTable()
#     mt.load_from_file("Data/todays/"+name)
    
#     past = HiFinder.StanderdStock(name)

#     avg = past.Low_mean_std()[0]
#     std = past.Low_mean_std()[1]
#     # print(avg,std)
#     mockrun = mt.get_column('o')
#     start = mockrun[0]
#     mockrun.pop(0)
#     for i,val in enumerate(mockrun):
#         if (start - (avg - std)) >=val:
            
#             user.liquid[name] = math.floor(amount_per_stock/val)
#             user.price[name] = val
#             user.cash = user.cash - (val * math.floor(amount_per_stock/val))
            
#             break

    

# stonks = []
# for val in user.liquid.keys():
#     # print(val)
#     stonks.append(val.replace(".csv",""))
# for i ,stock in enumerate(stonks):
#     TickerPuller.thisday(stock,int(day[i] + 86400 ))
#     time.sleep(1.1)

# for name in stocks:
#     mt = mypytable.MyPyTable()
#     mt.load_from_file("Data/todays/"+name)

#     past = HiFinder.StanderdStock(name)

#     avg = past.Hi_mean_std()[0]
#     std = past.Hi_mean_std()[1]
#     # print(avg,std)
#     mockrun = mt.get_column('o')
#     start = mockrun[0]
#     mockrun.pop(0)
#     for i,val in enumerate(mockrun):
#         if (start + (avg + std)) <=val:
            
#             user.cash = user.liquid[name] * val
#             user.profits +=  (user.liquid[name]*val) - (user.price[name]*user.liquid[name])

#             user.price[name] = 0
#             # user.cash = user.cash - (val * math.floor(amount_per_stock/val))
            
#             break

#         if i-1 == len(mockrun):
#             user.cash = user.liquid[name] * val
#             user.profits +=  (user.liquid[name]*val) - (user.price[name]*user.liquid[name])

#             user.price[name] = 0
#             print("Here")
    
# print(17.304999999999996)
# print(0.41)
# print(1.32)
# print(0.40500000000000114)
# print(user.profits)

# %%
# print(len(day))
# print(day)
# stonks = []
# for val in stocks:
#     print(val)
#     stonks.append(val.replace(".csv",""))
# for i ,stock in enumerate(stonks):
#     TickerPuller.thisday(stock,int(day[i]))
#     time.sleep(1.1)
# print(day)
# import imp
# import mypytable
# from Predicting import HiFinder 
# import math
# imp.reload(HiFinder)
# imp.reload(Portfolio)
# money = user.cash
# amount_per_stock = money/5
# for name in stocks:
#     mt = mypytable.MyPyTable()
#     mt.load_from_file("Data/todays/"+name)
    
#     past = HiFinder.StanderdStock(name)

#     avg = past.Low_mean_std()[0]
#     std = past.Low_mean_std()[1]
#     # print(avg,std)
#     mockrun = mt.get_column('o')
#     start = mockrun[0]
#     mockrun.pop(0)
#     for i,val in enumerate(mockrun):
#         if (start - (avg - std)) >=val:
            
#             user.liquid[name] = math.floor(amount_per_stock/val)
#             user.price[name] = val
#             user.cash = user.cash - (val * math.floor(amount_per_stock/val))
            
#             break

    

# stonks = []
# for val in user.liquid.keys():
#     # print(val)
#     stonks.append(val.replace(".csv",""))
# for i ,stock in enumerate(stonks):
#     TickerPuller.thisday(stock,int(day[i] + 86400 ))
#     time.sleep(1.1)

# for name in stocks:
#     mt = mypytable.MyPyTable()
#     mt.load_from_file("Data/todays/"+name)

#     past = HiFinder.StanderdStock(name)

#     avg = past.Hi_mean_std()[0]
#     std = past.Hi_mean_std()[1]
#     # print(avg,std)
#     mockrun = mt.get_column('o')
#     start = mockrun[0]
#     mockrun.pop(0)
#     for i,val in enumerate(mockrun):
#         if (start + (avg + std)) <=val:
            
#             user.cash = user.liquid[name] * val
#             user.profits +=  (user.liquid[name]*val) - (user.price[name]*user.liquid[name])

#             user.price[name] = 0
#             # user.cash = user.cash - (val * math.floor(amount_per_stock/val))
            
#             break

#         if i-1 == len(mockrun):
#             user.cash = user.liquid[name] * val
#             user.profits +=  (user.liquid[name]*val) - (user.price[name]*user.liquid[name])

#             user.price[name] = 0
#             print("Here")
    
# print(17.304999999999996)
# print(0.41)
# print(1.32)
# print(0.40500000000000114)
# print(user.profits)

# %%
# import imp
# import mypytable
# from Predicting import HiFinder 
# import math
# imp.reload(HiFinder)
# imp.reload(Portfolio)
# money = user.cash
# amount_per_stock = money/5
# for name in stocks:
#     mt = mypytable.MyPyTable()
#     mt.load_from_file("Data/todays/"+name)
    
#     past = HiFinder.StanderdStock(name)

#     avg = past.Low_mean_std()[0]
#     std = past.Low_mean_std()[1]
#     # print(avg,std)
#     mockrun = mt.get_column('o')
#     start = mockrun[0]
#     mockrun.pop(0)
#     for i,val in enumerate(mockrun):
#         if (start - (avg - std)) >=val:
            
#             user.liquid[name] = math.floor(amount_per_stock/val)
#             user.price[name] = val
#             user.cash = user.cash - (val * math.floor(amount_per_stock/val))
            
#             break

    

# stonks = []
# for val in user.liquid.keys():
#     # print(val)
#     stonks.append(val.replace(".csv",""))
# for i ,stock in enumerate(stonks):
#     TickerPuller.thisday(stock,int(day[i] + 86400 ))
#     time.sleep(1.1)

# for name in stocks:
#     mt = mypytable.MyPyTable()
#     mt.load_from_file("Data/todays/"+name)

#     past = HiFinder.StanderdStock(name)

#     avg = past.Hi_mean_std()[0]
#     std = past.Hi_mean_std()[1]
#     # print(avg,std)
#     mockrun = mt.get_column('o')
#     start = mockrun[0]
#     mockrun.pop(0)
#     for i,val in enumerate(mockrun):
#         if (start + (avg + std)) <=val:
            
#             user.cash = user.liquid[name] * val
#             user.profits +=  (user.liquid[name]*val) - (user.price[name]*user.liquid[name])

#             user.price[name] = 0
#             # user.cash = user.cash - (val * math.floor(amount_per_stock/val))
            
#             break

#         if i-1 == len(mockrun):
#             user.cash = user.liquid[name] * val
#             user.profits +=  (user.liquid[name]*val) - (user.price[name]*user.liquid[name])

#             user.price[name] = 0
#             print("Here")
    
# print(17.304999999999996)
# print(0.41)
# print(1.32)
# print(0.40500000000000114)
# print(user.profits)

# %%
# stonks = []
# for val in user.liquid.keys():
#     # print(val)
#     stonks.append(val.replace(".csv",""))
# for i ,stock in enumerate(stonks):
#     TickerPuller.thisday(stock,int(day[i] + 86400 ))
#     time.sleep(1.1)

# for name in stocks:
#     mt = mypytable.MyPyTable()
#     mt.load_from_file("Data/todays/"+name)

#     past = HiFinder.StanderdStock(name)

#     avg = past.Hi_mean_std()[0]
#     std = past.Hi_mean_std()[1]
#     # print(avg,std)
#     mockrun = mt.get_column('o')
#     start = mockrun[0]
#     mockrun.pop(0)
#     for i,val in enumerate(mockrun):
#         if (start + (avg + std)) <=val:
            
#             user.cash = user.liquid[name] * val
#             user.profits +=  (user.liquid[name]*val) - (user.price[name]*user.liquid[name])

#             user.price[name] = 0
#             # user.cash = user.cash - (val * math.floor(amount_per_stock/val))
            
#             break

#         if i-1 == len(mockrun):
#             user.cash = user.liquid[name] * val
#             user.profits +=  (user.liquid[name]*val) - (user.price[name]*user.liquid[name])

#             user.price[name] = 0
#             print("Here")
    
# print(17.304999999999996)
# print(0.41)
# print(1.32)
# print(0.40500000000000114)
# print(user.profits)

# %%
# ### Selling 

# # for val in user.liquid.keys():
# #     print(val)
    

# # print(len(day))
# # print(day)
# # stonks = []
# # for val in user.liquid.keys():
# #     # print(val)
# #     stonks.append(val.replace(".csv",""))
# # for i ,stock in enumerate(stonks):
# #     TickerPuller.thisday(stock,int(day[i] + 86400 ))
# #     time.sleep(1.1)
# # print(day)


# for name in stocks:
#     mt = mypytable.MyPyTable()
#     mt.load_from_file("Data/todays/"+name)

#     past = HiFinder.StanderdStock(name)

#     avg = past.Hi_mean_std()[0]
#     std = past.Hi_mean_std()[1]
#     # print(avg,std)
#     mockrun = mt.get_column('o')
#     start = mockrun[0]
#     mockrun.pop(0)
#     for i,val in enumerate(mockrun):
#         if (start + (avg + std)) <=val:
            
#             user.cash = user.liquid[name] * val
#             user.profits +=  (user.liquid[name]*val) - (user.price[name]*user.liquid[name])

#             user.price[name] = 0
#             # user.cash = user.cash - (val * math.floor(amount_per_stock/val))
            
#             break

#         if i-1 == len(mockrun):
#             user.cash = user.liquid[name] * val
#             user.profits +=  (user.liquid[name]*val) - (user.price[name]*user.liquid[name])

#             user.price[name] = 0
#             print("Here")
    
# print(17.304999999999996)
# print(0.41)
# print(1.32)
# print(0.40500000000000114)
# print(user.profits)
