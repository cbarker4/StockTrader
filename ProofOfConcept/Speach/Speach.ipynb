# %%
import speech_recognition as sr

# %%
from os import path
from pydub import AudioSegment

# %%
src = "/home/cbarker4/Documents/DataScience/StockTrader/Speach/Data/ie_04_10_2023.mp3"
out = "ie-04-10-2023.wav"

sound = AudioSegment.from_mp3(src)
sound.export(out, format="wav")
# Out:
# <_io.BufferedRandom name='ie-04-10-2023.wav'>

# %%
file = "ie-04-10-2023.wav"
r = sr.Recognizer()

# %%
# with sr.AudioFile(file) as source:
#     # listen for the data (load audio to memory)
#     audio_data = r.record(source)
#     # recognize (convert from speech to text)
#     text = r.recognize_google(audio_data)
#     print(text)

# %%
# importing libraries 
import speech_recognition as sr 
import os 
from pydub import AudioSegment
from pydub.silence import split_on_silence

# create a speech recognition object
r = sr.Recognizer()

# a function that splits the audio file into chunks
# and applies speech recognition
def get_large_audio_transcription(path):
    """
    Splitting the large audio file into chunks
    and apply speech recognition on each of these chunks
    """
    # open the audio file using pydub
    sound = AudioSegment.from_wav(path)  
    # split audio sound where silence is 700 miliseconds or more and get chunks
    chunks = split_on_silence(sound,
        # experiment with this value for your target audio file
        min_silence_len = 500,
        # adjust this per requirement
        silence_thresh = sound.dBFS-14,
        # keep the silence for 1 second, adjustable as well
        keep_silence=500,
    )
    folder_name = "audio-chunks"
    # create a directory to store the audio chunks
    if not os.path.isdir(folder_name):
        os.mkdir(folder_name)
    whole_text = ""
    # process each chunk 
    for i, audio_chunk in enumerate(chunks, start=1):
        # export audio chunk and save it in
        # the `folder_name` directory.
        chunk_filename = os.path.join(folder_name, f"chunk{i}.wav")
        audio_chunk.export(chunk_filename, format="wav")
        # recognize the chunk
        with sr.AudioFile(chunk_filename) as source:
            audio_listened = r.record(source)
            # try converting it to text
            try:
                text = r.recognize_google(audio_listened)
            except sr.UnknownValueError as e:
                print("Error:", str(e))
            else:
                text = f"{text.capitalize()}. "
                print(chunk_filename, ":", text)
                whole_text += text
    # return the text for all chunks detected
    return whole_text

# %%
path = "7601-291468-0006.wav"
print("\nFull text:", get_large_audio_transcription(file))
# Out:
# audio-chunks/chunk1.wav : At fred meyer we want our fresh produce to meet your expectations which is why we're dedicated to doing up to a 27 point inspection on our fruits and veggies checking for things like scarring in fact only the best produce like zesty oranges and crisp carrots reach our shelves because when it comes to fresh our higher standards mean pressure produce fred meyer fresh for everyone.
# audio-chunks/chunk2.wav : Investor's edge with gary kaltbaum straight talk about you and your money now from the best talk studios here is gary kaltbaum.
# audio-chunks/chunk3.wav : And work once again to investors edge on gary culp i'm your host a thanks for being with us today glad you here ladies and gentlemen happy that you are listening.
# audio-chunks/chunk4.wav : It's april 10th.
# audio-chunks/chunk5.wav : 2023 it is monday.
# audio-chunks/chunk6.wav : And let me just start off by saying.
# audio-chunks/chunk7.wav : At the end of each show.
# audio-chunks/chunk8.wav : We do a little.
# audio-chunks/chunk9.wav : Go home hug your family.
# audio-chunks/chunk10.wav : Hug your children.
# audio-chunks/chunk11.wav : They will feel better.
# audio-chunks/chunk12.wav : That you will feel better.
# audio-chunks/chunk13.wav : We started saying go home and hug your children.
# audio-chunks/chunk14.wav : The day of the columbine incident.
# audio-chunks/chunk15.wav : Columbine incident the columbine murders.
# audio-chunks/chunk16.wav : I i.
# audio-chunks/chunk17.wav : How many years ago was that hold on columbine.
# audio-chunks/chunk18.wav : April 20th 1999.
# audio-chunks/chunk19.wav : For almost.
# audio-chunks/chunk20.wav : 4 years.
# audio-chunks/chunk21.wav : I have been ending the show.
# audio-chunks/chunk22.wav : The same way.
# Error:
# audio-chunks/chunk24.wav : I don't want to get into why and it has nothing to do with my family.
# audio-chunks/chunk25.wav : But.
# Error:
# Error:
# audio-chunks/chunk28.wav : Hint.
# audio-chunks/chunk29.wav : As often as you can.
# audio-chunks/chunk30.wav : As often as you want.
# audio-chunks/chunk31.wav : Make sure your family and your kids.
# audio-chunks/chunk32.wav : Know how you feel about.
# audio-chunks/chunk33.wav : Has nothing to do i'm not mentioning it because of my family.
# audio-chunks/chunk34.wav : Just.
# audio-chunks/chunk35.wav : I'm mentioning it because of.
# audio-chunks/chunk36.wav : A families that i know.
# audio-chunks/chunk37.wav : Okay.
# audio-chunks/chunk38.wav : Right out of the box.
# audio-chunks/chunk39.wav : And since we mentioned 1999.
# audio-chunks/chunk40.wav : Oh that was the year that the bubble.
# audio-chunks/chunk41.wav : Of a.
# Error:
# audio-chunks/chunk43.wav : Set the stage for the worst bear market.
# audio-chunks/chunk44.wav : I think in history for the nasdaq that dropped 80% nasdaq 180%.
# audio-chunks/chunk45.wav : I out in 1999.
# audio-chunks/chunk46.wav : And since then.
# audio-chunks/chunk47.wav : We have stated to you.
# audio-chunks/chunk48.wav : Oh several thousand times.
# Error:
# audio-chunks/chunk50.wav : When all is said and done.
# audio-chunks/chunk51.wav : Watch the semic.
# audio-chunks/chunk52.wav : We're getting right into the crux of something here ladies.
# audio-chunks/chunk53.wav : This is what i've been saying to you.
# audio-chunks/chunk54.wav : Forever.
# audio-chunks/chunk55.wav : Since 2000.
# audio-chunks/chunk56.wav : I would suggest to you.
# audio-chunks/chunk57.wav : That 90 some odd percent of the time.
# audio-chunks/chunk58.wav : It's not a hundred.
# audio-chunks/chunk59.wav : Watch the semic.
# audio-chunks/chunk60.wav : They have been amazing.
# audio-chunks/chunk61.wav : Leaders to the upside.
# audio-chunks/chunk62.wav : And leaders to the down.
# audio-chunks/chunk63.wav : And what i mean by that is.
# audio-chunks/chunk64.wav : Kind of simple.
# audio-chunks/chunk65.wav : You can't have a real bull market.
# audio-chunks/chunk66.wav : Without the sem.
# audio-chunks/chunk67.wav : Now it used to be.
# audio-chunks/chunk68.wav : Financials.
# audio-chunks/chunk69.wav : And then it went to financials.
# audio-chunks/chunk70.wav : And semiconductors.
# audio-chunks/chunk71.wav : After 08.
# audio-chunks/chunk72.wav : We were able to back out.
# audio-chunks/chunk73.wav : The financials.
# audio-chunks/chunk74.wav : Because during 08.
# audio-chunks/chunk75.wav : 0708.
# audio-chunks/chunk76.wav : The market rallied without them.
# audio-chunks/chunk77.wav : And then of course.
# audio-chunks/chunk78.wav : They let the crash.
# audio-chunks/chunk79.wav : In a way.
# audio-chunks/chunk80.wav : One of our best calls in history.
# audio-chunks/chunk81.wav : Was it '07 that whole year.
# audio-chunks/chunk82.wav : We would just say to you something was wrong with the financial.
# audio-chunks/chunk83.wav : When the market i remember the down rally the thousand points.
# audio-chunks/chunk84.wav : And the financials couldn't bu.
# audio-chunks/chunk85.wav : The big financials.
# audio-chunks/chunk86.wav : With the dow rally 1,000 points.
# audio-chunks/chunk87.wav : And then when the dow came in a thousand.
# audio-chunks/chunk88.wav : They let down and let down badly.
# audio-chunks/chunk89.wav : And then when the market would rally up a little bit.
# audio-chunks/chunk90.wav : They were hesitant.
# audio-chunks/chunk91.wav : So they had this.
# audio-chunks/chunk92.wav : They lost the leadership quality.
# audio-chunks/chunk93.wav : But they showed us the way.
# audio-chunks/chunk94.wav : I'm a little did we have no idea.
# audio-chunks/chunk95.wav : That disaster lied ahead.
# audio-chunks/chunk96.wav : We had no idea.
# audio-chunks/chunk97.wav : Merrill.
# audio-chunks/chunk98.wav : Bear ste.
# audio-chunks/chunk99.wav : Countrywide financial wachov.
# audio-chunks/chunk100.wav : Who else went out.
# audio-chunks/chunk101.wav : Back.
# audio-chunks/chunk102.wav : We have no idea.
# audio-chunks/chunk103.wav : You know who did have an idea.
# audio-chunks/chunk104.wav : The market.
# audio-chunks/chunk105.wav : But since.
# audio-chunks/chunk106.wav : It's pretty much the semis.
# audio-chunks/chunk107.wav : And when we say lead.
# audio-chunks/chunk108.wav : Very simply.
# audio-chunks/chunk109.wav : They hold up best.
# audio-chunks/chunk110.wav : In good markets and corrections.
# audio-chunks/chunk111.wav : When they crack.
# audio-chunks/chunk112.wav : It will be indicative.
# audio-chunks/chunk113.wav : Of the rest of the market.
# audio-chunks/chunk114.wav : The eventuality.
# audio-chunks/chunk115.wav : Of the rest of the market.
# audio-chunks/chunk116.wav : And you don't have to believe me.
# audio-chunks/chunk117.wav : If you have some stock software.
# audio-chunks/chunk118.wav : That you can just go back my softwares allows me to go back.
# audio-chunks/chunk119.wav : Daily weekly and monthly.
# audio-chunks/chunk120.wav : To the beginning of time.
# audio-chunks/chunk121.wav : I can change the date.
# audio-chunks/chunk122.wav : And all i can tell you as i have done this study.
# audio-chunks/chunk123.wav : I don't think the word is uncann.
# audio-chunks/chunk124.wav : I just think.
# audio-chunks/chunk125.wav : How it is.
# audio-chunks/chunk126.wav : And and why would that be.
# audio-chunks/chunk127.wav : Well semiconductor chips.
# Error:
# audio-chunks/chunk129.wav : Everything.
# audio-chunks/chunk130.wav : Almost everything.
# audio-chunks/chunk131.wav : And they have basically moved the needle.
# audio-chunks/chunk132.wav : And why am i bringing them up today what what matters so much today.
# audio-chunks/chunk133.wav : Well this morning.
# audio-chunks/chunk134.wav : Very simply.
# audio-chunks/chunk135.wav : Nasdaq was getting smacked around.
# audio-chunks/chunk136.wav : And as you know the nasdaq's pretty important.
# audio-chunks/chunk137.wav : To the market as.
# audio-chunks/chunk138.wav : And guess what the semiconductors did.
# audio-chunks/chunk139.wav : And guess where they did it.
# audio-chunks/chunk140.wav : Well.
# audio-chunks/chunk141.wav : Number one.
# audio-chunks/chunk142.wav : They help.
# audio-chunks/chunk143.wav : What happened then.
# audio-chunks/chunk144.wav : Market follow.
# audio-chunks/chunk145.wav : Where do they hold.
# audio-chunks/chunk146.wav : What is the most important.
# audio-chunks/chunk147.wav : Area.
# audio-chunks/chunk148.wav : We have harped.
# audio-chunks/chunk149.wav : Forever.
# audio-chunks/chunk150.wav : Because it's simply works.
# audio-chunks/chunk151.wav : That area.
# audio-chunks/chunk152.wav : Where.
# audio-chunks/chunk153.wav : The big institutions.
# audio-chunks/chunk154.wav : Stand up.
# audio-chunks/chunk155.wav : To defend.
# audio-chunks/chunk156.wav : The 50-day moving average.
# audio-chunks/chunk157.wav : And as i go through.
# audio-chunks/chunk158.wav : Name after name after name after name.
# audio-chunks/chunk159.wav : Name after name.
# audio-chunks/chunk160.wav : After name.
# audio-chunks/chunk161.wav : After name.
# audio-chunks/chunk162.wav : Afternoon.
# audio-chunks/chunk163.wav : A bunch of semiconductor stocks today.
# audio-chunks/chunk164.wav : Along with the semiconductor index.
# audio-chunks/chunk165.wav : Held.
# audio-chunks/chunk166.wav : The 50-day moving average.
# audio-chunks/chunk167.wav : To the penny on some names.
# audio-chunks/chunk168.wav : The semiconductor index.
# audio-chunks/chunk169.wav : Undercut it by two points.
# audio-chunks/chunk170.wav : By the way.
# audio-chunks/chunk171.wav : Two points.
# audio-chunks/chunk172.wav : On an index that's over 3,000.
# audio-chunks/chunk173.wav : And they bounced.
# audio-chunks/chunk174.wav : Slash rallied up.
# audio-chunks/chunk175.wav : And market.
# audio-chunks/chunk176.wav : Got better throughout the day now does this mean.
# audio-chunks/chunk177.wav : They're going to get going no we didn't say that.
# audio-chunks/chunk178.wav : We just said they held.
# audio-chunks/chunk179.wav : Important area.
# audio-chunks/chunk180.wav : And again.
# audio-chunks/chunk181.wav : Market follow.
# audio-chunks/chunk182.wav : And a nasdaq that was getting blasted early.
# audio-chunks/chunk183.wav : Came back and followed.
# Error:
# audio-chunks/chunk185.wav : Now we got to see.
# audio-chunks/chunk186.wav : Whether they decide to.
# audio-chunks/chunk187.wav : Bust out of range.
# audio-chunks/chunk188.wav : If they do.
# audio-chunks/chunk189.wav : Market's going to be better.
# audio-chunks/chunk190.wav : If they don't.
# audio-chunks/chunk191.wav : Maybe they sit around.
# audio-chunks/chunk192.wav : If they break below.
# audio-chunks/chunk193.wav : Today.
# audio-chunks/chunk194.wav : And it's lowe's.
# audio-chunks/chunk195.wav : Could be of import.
# audio-chunks/chunk196.wav : So just letting you know.
# audio-chunks/chunk197.wav : When we give out the final numbers.
# audio-chunks/chunk198.wav : There wasn't a lot of big movement today.
# audio-chunks/chunk199.wav : Except for this area.
# audio-chunks/chunk200.wav : When we give out the numbers.
# audio-chunks/chunk201.wav : Will let you know that the institutions.
# audio-chunks/chunk202.wav : Boston market up.
# audio-chunks/chunk203.wav : In the last 10 minutes.
# Error:
# audio-chunks/chunk205.wav : Interesting.
# audio-chunks/chunk206.wav : What did they notice.
# audio-chunks/chunk207.wav : What did they react to.
# audio-chunks/chunk208.wav : The semic.
# audio-chunks/chunk209.wav : Again.
# audio-chunks/chunk210.wav : Once again.
# audio-chunks/chunk211.wav : Amazingly so.
# audio-chunks/chunk212.wav : And we'll see where it decides to take us.
# audio-chunks/chunk213.wav : It does not mean we get going.
# audio-chunks/chunk214.wav : Would just letting you know that today.
# audio-chunks/chunk215.wav : Today.
# audio-chunks/chunk216.wav : The market recognized it.
# Error:
# audio-chunks/chunk218.wav : Understood it.
# audio-chunks/chunk219.wav : Got better throughout the day.
# audio-chunks/chunk220.wav : And finished on the.
# audio-chunks/chunk221.wav : I think the high note of the day.
# audio-chunks/chunk222.wav : And that's the story.
# audio-chunks/chunk223.wav : And we do our webcast.
# audio-chunks/chunk224.wav : And we do our scans.
# audio-chunks/chunk225.wav : It's amazing.
# audio-chunks/chunk226.wav : How we look at photo albums.
# audio-chunks/chunk227.wav : Looking for familiar faces.
# audio-chunks/chunk228.wav : And those familiar faces continue to show up.
# audio-chunks/chunk229.wav : Up next today's market rap.
# audio-chunks/chunk230.wav : And anything else i'm gary this is the one only investors edge.
# Error:
# audio-chunks/chunk232.wav : Hi i'm gary kalbaum hosted a nationally syndicated radio show investors edge we're not just handsome radio people we manage investors money for a living specializing in fee-based discretionary money management no big commissions just a fee on the assets that's managed we also provide a full range of personalized services including retirement planning fixed income and educational needs all to assist you and achieving your financial goals understanding not all individuals have the same needs will carefully evaluate your personal goals to determine a proper investment strategy if your current approach to investing is not getting you to where you would like to be call us to make an appointment for a complimentary portfolio review the number to call is 888-422-559 that's 8888-422-559 that's 888-422-559 advisory services.
# audio-chunks/chunk233.wav : With one of the best savings rates in america banking with capital one is the easiest decision in the history of decisions even easier than choosing slash to be in your band guitar you're in.
# audio-chunks/chunk234.wav : Cool yep even easier than that and with no fees or minimums on checking and savings accounts is it even a decision that's banking reimagined what's in your wallet in terms apply see capitalone.com/bank for details capital one and a member fdic it's a brave new world in media with hundreds of videos hey siri.
# audio-chunks/chunk235.wav : It's time to switch on the integrator units and get the brain cells working you're listening tooth once again all right today's market.com.
# audio-chunks/chunk236.wav : No gray areas with the man you're either in or out of the market was proprietary indicators go check it out.
# audio-chunks/chunk237.wav : Investment.
# audio-chunks/chunk238.wav : Dashmodels.com now i'm going to give you out the final dow first.
# audio-chunks/chunk239.wav : It was only up 100.
# audio-chunks/chunk240.wav : But i have to tell you.
# audio-chunks/chunk241.wav : It was.
# audio-chunks/chunk242.wav : The whole day.
# audio-chunks/chunk243.wav : It was never more than 60.
# audio-chunks/chunk244.wav : In the last 30 seconds at r.
# audio-chunks/chunk245.wav : 60 points to be up a.
# audio-chunks/chunk246.wav : Write the clothes.
# audio-chunks/chunk247.wav : At the s&p only finished up for.
# audio-chunks/chunk248.wav : And of course that same thing.
# audio-chunks/chunk249.wav : The nasdaq finished down three.
# audio-chunks/chunk250.wav : Finish down three.
# audio-chunks/chunk251.wav : At the low today the nasdaq was 11924.
# audio-chunks/chunk252.wav : It's not 157.
# audio-chunks/chunk253.wav : These socks at the low today was $3,042.
# audio-chunks/chunk254.wav : The 50-day moving average 3044.
# audio-chunks/chunk255.wav : It finished the 3126.
# audio-chunks/chunk256.wav : Up 55.
# audio-chunks/chunk257.wav : Just improvement throughout the whole day.
# audio-chunks/chunk258.wav : The semis.
# audio-chunks/chunk259.wav : And let me be clear about how this works.
# audio-chunks/chunk260.wav : These big institutions will recognize.
# audio-chunks/chunk261.wav : When something's being defended.
# audio-chunks/chunk262.wav : Or something is cracking.
# audio-chunks/chunk263.wav : That's the strength.
# audio-chunks/chunk264.wav : That's our edge.
# audio-chunks/chunk265.wav : That's what happened today.
# audio-chunks/chunk266.wav : Does it mean anything for tomorrow.
# audio-chunks/chunk267.wav : Well since we don't have a real big trend.
# audio-chunks/chunk268.wav : Not yet.
# audio-chunks/chunk269.wav : But you never know if it starts.
# audio-chunks/chunk270.wav : And if you look at the semiconductor index you will notice.
# audio-chunks/chunk271.wav : On march 13th it undercut.
# audio-chunks/chunk272.wav : The 50-day moving average and got back above.
# audio-chunks/chunk273.wav : On march 15th.
# audio-chunks/chunk274.wav : It hit the 50-day moving average within two points.
# audio-chunks/chunk275.wav : On march 28th.
# audio-chunks/chunk276.wav : Got within 15 points.
# audio-chunks/chunk277.wav : On thursday hit it within a few points and today the same.
# audio-chunks/chunk278.wav : That is what we call.
# audio-chunks/chunk279.wav : Symmetry.
# audio-chunks/chunk280.wav : What does that mean symmetry.
# audio-chunks/chunk281.wav : Oh it's simply means that.
# audio-chunks/chunk282.wav : There is a recognition of.
# audio-chunks/chunk283.wav : Support.
# audio-chunks/chunk284.wav : And keep in mind the 50-day moving average is not stagnant.
# audio-chunks/chunk285.wav : It is a moving target.
# audio-chunks/chunk286.wav : As price moves up the 50-day moving average moves up as price moves down.
# audio-chunks/chunk287.wav : The the opposite.
# audio-chunks/chunk288.wav : And what the 50-day moving averages you just adding up the last 50 days the closes.
# audio-chunks/chunk289.wav : Get your number divide by 50 and it's a smooth out.
# Error:
# audio-chunks/chunk291.wav : Versus all the squiggly wigglies.
# audio-chunks/chunk292.wav : Of the daily moves.
# audio-chunks/chunk293.wav : And all we can tell you is through.
# audio-chunks/chunk294.wav : History.
# audio-chunks/chunk295.wav : And then we're going back ages.
# audio-chunks/chunk296.wav : It is the definable area.
# audio-chunks/chunk297.wav : And when i was scanning throughout the day i found.
# audio-chunks/chunk298.wav : 15 to 20 of the semiconductor names that tagged it and bounc.
# audio-chunks/chunk299.wav : Tagged it and bounc.
# audio-chunks/chunk300.wav : And then there was some other names outside of the semis that tagged it.
# audio-chunks/chunk301.wav : And bounce.
# audio-chunks/chunk302.wav : Will it continue.
# audio-chunks/chunk303.wav : We'll see.
# audio-chunks/chunk304.wav : Success.
# audio-chunks/chunk305.wav : Today.
# audio-chunks/chunk306.wav : That's what happened today and i say that with the nasdaq down three nasdaq 100 down 11.
# audio-chunks/chunk307.wav : But as i said the nasdaq was down 160 something.
# audio-chunks/chunk308.wav : Early in the day.
# audio-chunks/chunk309.wav : So we're going to chalk this up.
# audio-chunks/chunk310.wav : To a very good day.
# audio-chunks/chunk311.wav : And if.
# audio-chunks/chunk312.wav : Nas.
# audio-chunks/chunk313.wav : As we enter earnings can break above.
# audio-chunks/chunk314.wav : The last seven days.
# audio-chunks/chunk315.wav : That would be muy importante.
# audio-chunks/chunk316.wav : Same for the nasdaq 100.
# audio-chunks/chunk317.wav : Same for the s&p.
# audio-chunks/chunk318.wav : All sitting in tight action right here.
# audio-chunks/chunk319.wav : And we're not even going to say what odds favor.
# audio-chunks/chunk320.wav : We'll just react if it happens.
# audio-chunks/chunk321.wav : That's all we wanted to do.
# audio-chunks/chunk322.wav : And what's our edge.
# audio-chunks/chunk323.wav : 99.9% of wall street doesn't follow this.
# audio-chunks/chunk324.wav : And even if they did they wouldn't know what to do with.
# audio-chunks/chunk325.wav : As as we've told you wall street is fully invested vehicle.
# audio-chunks/chunk326.wav : Fully invested vehicle.
# audio-chunks/chunk327.wav : Come heck or high water.
# audio-chunks/chunk328.wav : Watch the guy on tv today come out.
# audio-chunks/chunk329.wav : Oh i'm bullish i'm buy.
# audio-chunks/chunk330.wav : Wait a minute.
# audio-chunks/chunk331.wav : Even 100% invested.
# audio-chunks/chunk332.wav : You have no cash how you buying.
# audio-chunks/chunk333.wav : Oh i'm going on tv so i got to tell people on both but you're in bullish all the way down.
# audio-chunks/chunk334.wav : By the way that would be me interviewing.
# audio-chunks/chunk335.wav : We got these people's number.
# audio-chunks/chunk336.wav : The numbers up.
# audio-chunks/chunk337.wav : My favorite one is the person.
# audio-chunks/chunk338.wav : Been saying to buy tesla all the way down.
# audio-chunks/chunk339.wav : It finally had a good rally.
# audio-chunks/chunk340.wav : Gets on the tube.
# audio-chunks/chunk341.wav : Gives himself a pat on the back.
# audio-chunks/chunk342.wav : Even though we was telling me to buy it 400 $35,300 25200.
# audio-chunks/chunk343.wav : We call that the broken clock syndrome.
# audio-chunks/chunk344.wav : And we also call it the charlatans syndrome.
# audio-chunks/chunk345.wav : We hate charlatans in this business.
# audio-chunks/chunk346.wav : And there's a lot of them.
# audio-chunks/chunk347.wav : And if you don't know what a charlatan is.
# audio-chunks/chunk348.wav : I put it away they simply pretend to be something they are not.
# audio-chunks/chunk349.wav : That's all.
# audio-chunks/chunk350.wav : So good day.
# audio-chunks/chunk351.wav : And the nasdaq was down.
# audio-chunks/chunk352.wav : Good day.
# audio-chunks/chunk353.wav : S&p was up in measly four points.
# audio-chunks/chunk354.wav : Good day the dow was up 100 which doesn't mean a lot to us.
# audio-chunks/chunk355.wav : It's where it was and where it finished.
# audio-chunks/chunk356.wav : That's what we define.
# audio-chunks/chunk357.wav : As a good day.
# audio-chunks/chunk358.wav : Now friday starts.
# audio-chunks/chunk359.wav : Massive amounts.
# audio-chunks/chunk360.wav : Of reports.
# audio-chunks/chunk361.wav : Not number but names.
# audio-chunks/chunk362.wav : On friday.
# audio-chunks/chunk363.wav : Jp morgan.
# audio-chunks/chunk364.wav : Wells fargo city group black rock.
# audio-chunks/chunk365.wav : Pnc bank.
# audio-chunks/chunk366.wav : And the most important.
# audio-chunks/chunk367.wav : Down.
# audio-chunks/chunk368.wav : Because of price because it's price weighted united health up at 515 name will be reporting.
# audio-chunks/chunk369.wav : Estimates it to be up about 11% in earnings.
# audio-chunks/chunk370.wav : They usually beat.
# audio-chunks/chunk371.wav : We'll see what that means.
# audio-chunks/chunk372.wav : The managed care stocks have been very weak until medicare decided to give them a crap load of money.
# audio-chunks/chunk373.wav : In the latest style you know every year they come out okay this is what we're going to pay you.
# audio-chunks/chunk374.wav : By the way have you ever been in hospitals these days.
# audio-chunks/chunk375.wav : How big they are how you got gigantic they are.
# audio-chunks/chunk376.wav : I was in one in lauderdale.
# audio-chunks/chunk377.wav : In hollywood florida this weekend.
# audio-chunks/chunk378.wav : Oh my goodness.
# Error:
# audio-chunks/chunk380.wav : They're like a city.
# audio-chunks/chunk381.wav : These hospitals.
# audio-chunks/chunk382.wav : How do they get paid.
# audio-chunks/chunk383.wav : You got it.
# audio-chunks/chunk384.wav : Think i'm in the wrong business.
# audio-chunks/chunk385.wav : I should own hospitals or storage.
# audio-chunks/chunk386.wav : Remember my story in college i had to put the in the summer i put stuff in storage and i told her buddy man we should.
# audio-chunks/chunk387.wav : Start a business just storage.
# audio-chunks/chunk388.wav : Damn what a doofus.
# audio-chunks/chunk389.wav : The stock called public storage psa.
# Error:
# audio-chunks/chunk391.wav : Totally do a storage.
# audio-chunks/chunk392.wav : It's been around since.
# audio-chunks/chunk393.wav : Forever.
# audio-chunks/chunk394.wav : That was seven bucks in 1990 it's a 300 today.
# audio-chunks/chunk395.wav : Storage.
# audio-chunks/chunk396.wav : Up next.
# audio-chunks/chunk397.wav : This that the other thing or whatever else i'm gary that's the one only investors edge.
# audio-chunks/chunk398.wav : You are listening to me please.
# audio-chunks/chunk399.wav : So.
# audio-chunks/chunk400.wav : There is.
# audio-chunks/chunk401.wav : A lot of talk that.
# audio-chunks/chunk402.wav : We're going to have a credit crunch.
# audio-chunks/chunk403.wav : Our answer to that.
# audio-chunks/chunk404.wav : Will let the market.
# audio-chunks/chunk405.wav : Dictate policy.
# audio-chunks/chunk406.wav : The market will tell us.
# audio-chunks/chunk407.wav : If they're big trouble lies ahead.
# audio-chunks/chunk408.wav : Whipping told.
# audio-chunks/chunk409.wav : That we're going to have a big recession.
# audio-chunks/chunk410.wav : If not worse.
# audio-chunks/chunk411.wav : Will.
# audio-chunks/chunk412.wav : The market decide.
# audio-chunks/chunk413.wav : If we're going to have a big recession a deep recession.
# audio-chunks/chunk414.wav : The market.
# audio-chunks/chunk415.wav : Will know it.
# audio-chunks/chunk416.wav : We're being told.
# audio-chunks/chunk417.wav : Let the dollar is going to go by the way of the.
# audio-chunks/chunk418.wav : Dodo bird.
# audio-chunks/chunk419.wav : That noise has been picking up a lot in the last week.
# audio-chunks/chunk420.wav : Interesting the dollar was strong today.
# audio-chunks/chunk421.wav : We'll just watch the market.
# audio-chunks/chunk422.wav : The market will let us know.
# audio-chunks/chunk423.wav : If we the dollar goes by.
# audio-chunks/chunk424.wav : The way of the dodo bird.
# audio-chunks/chunk425.wav : We're being told oh i've told you.
# audio-chunks/chunk426.wav : Burning stink.
# audio-chunks/chunk427.wav : We're being told.
# audio-chunks/chunk428.wav : We're heading into even worse earnings into a deep.
# audio-chunks/chunk429.wav : Earnings recession.
# audio-chunks/chunk430.wav : Will let the market decide.
# audio-chunks/chunk431.wav : We'll just watch the market.
# audio-chunks/chunk432.wav : The market will tell us.
# audio-chunks/chunk433.wav : Everything we need to know.
# audio-chunks/chunk434.wav : We're being told.
# audio-chunks/chunk435.wav : Buy some.
# audio-chunks/chunk436.wav : Inflation.
# audio-chunks/chunk437.wav : Is going to accelerate.
# audio-chunks/chunk438.wav : And of course oil prices have backed up a little bit.
# audio-chunks/chunk439.wav : Went up a little bit because of opec.
# audio-chunks/chunk440.wav : If.
# audio-chunks/chunk441.wav : Inflation gets really out of hand again.
# audio-chunks/chunk442.wav : Really starts to accelerate.
# audio-chunks/chunk443.wav : That means the fed's going to have to continue to do what they're doing.
# audio-chunks/chunk444.wav : And probably means trouble for the market.
# audio-chunks/chunk445.wav : But.
# audio-chunks/chunk446.wav : Will at the market decide.
# audio-chunks/chunk447.wav : The market will tell us everything we need to know.
# audio-chunks/chunk448.wav : If the markets decide to.
# audio-chunks/chunk449.wav : Croak.
# audio-chunks/chunk450.wav : It'll let us know.
# audio-chunks/chunk451.wav : As we will go into major downtrends.
# audio-chunks/chunk452.wav : There are others.
# audio-chunks/chunk453.wav : That are saying we're going into.
# audio-chunks/chunk454.wav : A deflationary.
# audio-chunks/chunk455.wav : Depression.
# audio-chunks/chunk456.wav : No they are they're out there.
# audio-chunks/chunk457.wav : Will let you know.
# audio-chunks/chunk458.wav : Which is going to let the market decide.
# audio-chunks/chunk459.wav : The market will tell us everything we need to know.
# audio-chunks/chunk460.wav : We'll just watch price.
# audio-chunks/chunk461.wav : And we'll just watch the market.
# audio-chunks/chunk462.wav : There's not many people.
# audio-chunks/chunk463.wav : Not tonight.
# audio-chunks/chunk464.wav : We'll scan 15000 names.
# audio-chunks/chunk465.wav : 200 sectors with sub sectors.
# audio-chunks/chunk466.wav : Every country every commodity.
# audio-chunks/chunk467.wav : Just to get a feel on what the heck is going on.
# audio-chunks/chunk468.wav : We will.
# audio-chunks/chunk469.wav : You know why we will.
# audio-chunks/chunk470.wav : Cuz we want to stay.
# audio-chunks/chunk471.wav : Ahead.
# audio-chunks/chunk472.wav : Of the game.
# audio-chunks/chunk473.wav : And by the way it's no game to us.
# audio-chunks/chunk474.wav : That's why.
# audio-chunks/chunk475.wav : It's quite simple.
# audio-chunks/chunk476.wav : For us.
# audio-chunks/chunk477.wav : We will work harder.
# audio-chunks/chunk478.wav : And longer.
# audio-chunks/chunk479.wav : And smarter.
# audio-chunks/chunk480.wav : Then everybody else.
# audio-chunks/chunk481.wav : In this industry.
# audio-chunks/chunk482.wav : That will not.
# audio-chunks/chunk483.wav : Guarantee.
# audio-chunks/chunk484.wav : Wins or losses.
# audio-chunks/chunk485.wav : It will guarantee.
# audio-chunks/chunk486.wav : That will have a very good feel.
# audio-chunks/chunk487.wav : I'm just what the heck is going on out there.
# audio-chunks/chunk488.wav : And as always.
# audio-chunks/chunk489.wav : Try to put our best foot forward.
# audio-chunks/chunk490.wav : Simple as that.
# audio-chunks/chunk491.wav : With no agenda.
# audio-chunks/chunk492.wav : Bias.
# audio-chunks/chunk493.wav : Ulterior motive.
# audio-chunks/chunk494.wav : Will let the market decide.
# audio-chunks/chunk495.wav : I have news for each and every one of you.
# audio-chunks/chunk496.wav : You can't hide bear markets you know how you know you're in a bear market.
# audio-chunks/chunk497.wav : Try buying something.
# audio-chunks/chunk498.wav : You know how you're in a bull market.
# audio-chunks/chunk499.wav : Sell something.
# audio-chunks/chunk500.wav : And watch it keep going up.
# audio-chunks/chunk501.wav : We try to simplify things for your kids.
# audio-chunks/chunk502.wav : And it's still ain't easy.
# audio-chunks/chunk503.wav : We have outlined road maps we did not invent it.
# audio-chunks/chunk504.wav : We did not invent it some of the greatest technicians on earth.
# audio-chunks/chunk505.wav : Did.
# audio-chunks/chunk506.wav : We studied them.
# audio-chunks/chunk507.wav : We studied under them.
# audio-chunks/chunk508.wav : We studied with them.
# audio-chunks/chunk509.wav : We learned.
# audio-chunks/chunk510.wav : We learned from some of the greatest hedge fund managers.
# audio-chunks/chunk511.wav : Like a pull tudor jones with one time he said these following words.
# audio-chunks/chunk512.wav : I know many other people that have a better win rate than me.
# audio-chunks/chunk513.wav : And a much better win rate than me.
# audio-chunks/chunk514.wav : Then i.
# audio-chunks/chunk515.wav : But.
# audio-chunks/chunk516.wav : It's what i do when i'm wrong.
# audio-chunks/chunk517.wav : That has me beaten their asses.
# audio-chunks/chunk518.wav : I don't think you said ass.
# audio-chunks/chunk519.wav : When wrong be wrong fast and be wrong small went right try to let him run as far as the ice can see.
# audio-chunks/chunk520.wav : But gary haven't you sold something off.
# audio-chunks/chunk521.wav : After losing a little bit and then it's skyrocketed oh yes.
# audio-chunks/chunk522.wav : Full and fair disclosure.
# audio-chunks/chunk523.wav : Some of my good wins though.
# audio-chunks/chunk524.wav : We're buying something a third and fourth time.
# audio-chunks/chunk525.wav : Cuz you never know when you're buying something it's just not the right time the right market.
# audio-chunks/chunk526.wav : So what you have to do is be.
# audio-chunks/chunk527.wav : Persistent.
# audio-chunks/chunk528.wav : And stay on top and again.
# audio-chunks/chunk529.wav : No bias.
# audio-chunks/chunk530.wav : No agenda no alternative.
# audio-chunks/chunk531.wav : You see what you see you know what it looks like.
# audio-chunks/chunk532.wav : You looking at a photo album for familiar faces.
# audio-chunks/chunk533.wav : And look what i found.
# audio-chunks/chunk534.wav : And bill o'neill is famous.
# audio-chunks/chunk535.wav : Gets asked about a stock.
# audio-chunks/chunk536.wav : He'll say well it looks like so and so from 1957.
# audio-chunks/chunk537.wav : And then you go look at the chart from so-and-so 1957 and yeah.
# audio-chunks/chunk538.wav : That's how much time and effort that man put in.
# audio-chunks/chunk539.wav : That's how much time and effort we have put in.
# audio-chunks/chunk540.wav : And it's still not easy.
# audio-chunks/chunk541.wav : These days we're dealing with so much more.
# audio-chunks/chunk542.wav : Then we used to have to deal with namely.
# audio-chunks/chunk543.wav : The interference of a select few people playing god.
# audio-chunks/chunk544.wav : With our lives.
# audio-chunks/chunk545.wav : At our future in the markets.
# audio-chunks/chunk546.wav : With them moronic imbecile.
# audio-chunks/chunk547.wav : Debt laden decision making.
# audio-chunks/chunk548.wav : Power hungry maniacs.
# audio-chunks/chunk549.wav : That's why.
# audio-chunks/chunk550.wav : Every night.
# audio-chunks/chunk551.wav : Regardless of the news.
# audio-chunks/chunk552.wav : We put our head down.
# audio-chunks/chunk553.wav : And we scan.
# audio-chunks/chunk554.wav : With no agenda.
# audio-chunks/chunk555.wav : Ulterior motive and bias.
# audio-chunks/chunk556.wav : I can tell you flat out.
# audio-chunks/chunk557.wav : If you just listen to some of the news right now a lot of the news right now.
# audio-chunks/chunk558.wav : Hey taiwan's going to be invaded by china.
# audio-chunks/chunk559.wav : That russia ukraine thing still going on.
# audio-chunks/chunk560.wav : The list goes on and on.
# audio-chunks/chunk561.wav : I have to tell you if i was just listening to the news.
# audio-chunks/chunk562.wav : I have my head under the blanket and never spy another sock.
# audio-chunks/chunk563.wav : But we know differently.
# audio-chunks/chunk564.wav : We'll just keep paying attention.
# audio-chunks/chunk565.wav : Markets are a treasure hunt.
# audio-chunks/chunk566.wav : Very often you have to be very very patient with them.
# audio-chunks/chunk567.wav : Bill bear markets will prey on your wallet.
# audio-chunks/chunk568.wav : Also pray on your psychology.
# audio-chunks/chunk569.wav : We won't let it happen to us.
# audio-chunks/chunk570.wav : And we will not be influenced.
# audio-chunks/chunk571.wav : By the perma bulls.
# audio-chunks/chunk572.wav : For the perm bears.
# audio-chunks/chunk573.wav : They are of no help.
# audio-chunks/chunk574.wav : The perma bills are a no help in a bear market the perma bears are no help in a bull market.
# audio-chunks/chunk575.wav : They never change their stripes so why even.
# audio-chunks/chunk576.wav : Pay attention.
# audio-chunks/chunk577.wav : We don't.
# audio-chunks/chunk578.wav : It just shows up.
# audio-chunks/chunk579.wav : Sometimes you just.
# audio-chunks/chunk580.wav : In life.
# audio-chunks/chunk581.wav : You see it.
# audio-chunks/chunk582.wav : We don't react to them.
# audio-chunks/chunk583.wav : We react to what the market tells us.
# audio-chunks/chunk584.wav : Up next.
# audio-chunks/chunk585.wav : News of the day.
# audio-chunks/chunk586.wav : This is the one only investors edge.
# Error:
# audio-chunks/chunk588.wav : You're listening to you.
# Error:
# audio-chunks/chunk590.wav : And work once again to investors edge again thanks for being with us today.
# audio-chunks/chunk591.wav : Are in the news.
# Error:
# audio-chunks/chunk593.wav : Unfortunately.
# audio-chunks/chunk594.wav : It looks like a small bank in louisville and next employee went in there and shot it up.
# audio-chunks/chunk595.wav : Multiple people.
# audio-chunks/chunk596.wav : Are.
# audio-chunks/chunk597.wav : One police officer.
# Error:
# audio-chunks/chunk599.wav : Shot in the head looks like a.
# audio-chunks/chunk600.wav : I guess a suicidal louisville bank employee.
# audio-chunks/chunk601.wav : I shot dead for co-workers.
# audio-chunks/chunk602.wav : Injured nine others.
# Error:
# audio-chunks/chunk604.wav : He lost his job.
# audio-chunks/chunk605.wav : I'm going to go murder people.
# audio-chunks/chunk606.wav : Looks like i don't know whether he killed himself or whether a cop.
# Error:
# audio-chunks/chunk608.wav : Police officer took him down.
# audio-chunks/chunk609.wav : As usual.
# audio-chunks/chunk610.wav : The talk about guns pervades the air.
# audio-chunks/chunk611.wav : We just want you to remember something and again we say this with no agenda ulterior motive in no bias whatsoever.
# audio-chunks/chunk612.wav : Other republican side.
# audio-chunks/chunk613.wav : Won't do anything.
# audio-chunks/chunk614.wav : We already know that.
# audio-chunks/chunk615.wav : But the democratic sign they're just full of crap.
# audio-chunks/chunk616.wav : They've had ample opportunity to do whatever they want to do.
# audio-chunks/chunk617.wav : Obama had a supermajority could have done whatever he wanted to do.
# audio-chunks/chunk618.wav : Biden did not have one but he had.
# audio-chunks/chunk619.wav : All.
# Error:
# audio-chunks/chunk621.wav : Parts of government.
# audio-chunks/chunk622.wav : And the bully pulpit.
# audio-chunks/chunk623.wav : What did he do.
# audio-chunks/chunk624.wav : He did nothing.
# audio-chunks/chunk625.wav : We just want you to remember that.
# audio-chunks/chunk626.wav : The reason why the democrats won't do anything.
# audio-chunks/chunk627.wav : And just flap their gums all the time.
# audio-chunks/chunk628.wav : It goes back to why one of the big reasons they lost in 94.
# audio-chunks/chunk629.wav : Was the.
# audio-chunks/chunk630.wav : Assault weapons ban.
# audio-chunks/chunk631.wav : That's what they blame on losing and they don't want that to happen again.
# audio-chunks/chunk632.wav : Would just telling you.
# audio-chunks/chunk633.wav : You go back and read it yourself.
# audio-chunks/chunk634.wav : We're tired of both parties.
# Error:
# audio-chunks/chunk636.wav : And would particularly tired of any of them that flap the gums you know like joe mansion.
# audio-chunks/chunk637.wav : The the supposed moderate that signed off on a 1.8 trillion dollar spending bill with $380 billion of our tax dollars going to one man john podesta a democratic hack to give out for climate.
# audio-chunks/chunk638.wav : Joe manchester and now he's complaining he got he got lied to no no crap.
# audio-chunks/chunk639.wav : So we just want to let you know every time you hear the gun thing.
# audio-chunks/chunk640.wav : And just so you know i'm.
# audio-chunks/chunk641.wav : I believe in.
# audio-chunks/chunk642.wav : The americans' ability to defend themselves.
# audio-chunks/chunk643.wav : I believe in that amendment.
# audio-chunks/chunk644.wav : I really do.
# audio-chunks/chunk645.wav : But.
# audio-chunks/chunk646.wav : Nobody does anything.
# audio-chunks/chunk647.wav : Let no movement zero.
# Error:
# audio-chunks/chunk649.wav : Nothing.
# audio-chunks/chunk650.wav : Nothing.
# audio-chunks/chunk651.wav : And we can get into it for 2 hours.
# audio-chunks/chunk652.wav : Did you get my point.
# audio-chunks/chunk653.wav : It's a fruitless endeavor of flapping gums.
# audio-chunks/chunk654.wav : That's what it is a fruitless endeavor.
# audio-chunks/chunk655.wav : A flapping gums.
# audio-chunks/chunk656.wav : Remember this crime.
# audio-chunks/chunk657.wav : They are outlier events.
# audio-chunks/chunk658.wav : But.
# audio-chunks/chunk659.wav : A death is a death.
# audio-chunks/chunk660.wav : I will say a little.
# audio-chunks/chunk661.wav : Prayer for.
# audio-chunks/chunk662.wav : You know whoever reading about this a lot these days.
# Error:
# audio-chunks/chunk664.wav : In the news.
# audio-chunks/chunk665.wav : I love how.
# audio-chunks/chunk666.wav : Now.
# audio-chunks/chunk667.wav : Everybody agrees with us.
# audio-chunks/chunk668.wav : What are we telling you about bubbles.
# audio-chunks/chunk669.wav : Who created.
# audio-chunks/chunk670.wav : Oh wall street journal op-ed turn off the fed bubble machine that's the headline.
# audio-chunks/chunk671.wav : Trying to ramp up applicant demand serves no purpose of supplies constrained the guy named andy kessler he's i guess he writes off beds for the wall street journal guess what he's telling you now we told you years ago.
# audio-chunks/chunk672.wav : Got to get rid of the central bankers.
# audio-chunks/chunk673.wav : They should not be able to print a 9 trillion bucks take rates to 0% and screw everybody.
# audio-chunks/chunk674.wav : And then create bubbles and then the bubbles pop and everybody loses.
# Error:
# audio-chunks/chunk676.wav : So there's another person and now agrees with everything we've been telling you.
# audio-chunks/chunk677.wav : For years.
# audio-chunks/chunk678.wav : Seriously.
# audio-chunks/chunk679.wav : In the news.
# Error:
# audio-chunks/chunk681.wav : Speaking of the fed.
# audio-chunks/chunk682.wav : You know what they're doing some studying.
# audio-chunks/chunk683.wav : Something that not even supposed to be involved in.
# audio-chunks/chunk684.wav : The climate hoax.
# audio-chunks/chunk685.wav : The fed is forcing big banks to produce complex reports.
# audio-chunks/chunk686.wav : On their climate vulnerability.
# audio-chunks/chunk687.wav : What.
# audio-chunks/chunk688.wav : What.
# audio-chunks/chunk689.wav : The san francisco fed host of the conference on climate change in may.
# audio-chunks/chunk690.wav : 27 fat economist participated.
# audio-chunks/chunk691.wav : You think they produce any research.
# audio-chunks/chunk692.wav : High quality research.
# audio-chunks/chunk693.wav : They did a couple of studies.
# audio-chunks/chunk694.wav : My 12-year-old goddaughter to do a better one.
# audio-chunks/chunk695.wav : The central bankers that have no clue.
# audio-chunks/chunk696.wav : What's going on.
# audio-chunks/chunk697.wav : I'm now getting at the climate.
# audio-chunks/chunk698.wav : Feel better now.
# audio-chunks/chunk699.wav : That was in the news.
# audio-chunks/chunk700.wav : In the news.
# audio-chunks/chunk701.wav : Did you watch the masters.
# audio-chunks/chunk702.wav : I was supposed to go on saturday i'm so glad i didn't go it got rained out i would have been really po'd.
# audio-chunks/chunk703.wav : John rom.
# audio-chunks/chunk704.wav : Great player wanted brooks koepka faded.
# audio-chunks/chunk705.wav : Phil mickelson end up second place.
# audio-chunks/chunk706.wav : 52 years old.
# audio-chunks/chunk707.wav : Was throwing darts at the end.
# audio-chunks/chunk708.wav : Awesome.
# audio-chunks/chunk709.wav : If you've never been to the masters and you like golf you got to go once.
# audio-chunks/chunk710.wav : Just so you know what you got to get in the lottery to get the cheap tickets after that you're paying some bucks.
# audio-chunks/chunk711.wav : Sandwiches are a buck 50 to 2 1/2 bucks they sell a million dollars of in their stores when you there an hour.
# audio-chunks/chunk712.wav : What are most beautiful serene places on earth.
# audio-chunks/chunk713.wav : If you are a golfer as you walk in to the place.
# audio-chunks/chunk714.wav : You're mesmerized.
# audio-chunks/chunk715.wav : So just letting you know if you never been there.
# audio-chunks/chunk716.wav : Do it once i i've been there three times and i'm pissed off i haven't been there more.
# audio-chunks/chunk717.wav : I'll be going next year.
# audio-chunks/chunk718.wav : I still have never won the lottery though.
# audio-chunks/chunk719.wav : I think i've been doing that for 30 years.
# audio-chunks/chunk720.wav : That was the masters nba season the playins start in the next couple of days and then we go to the playoffs.
# audio-chunks/chunk721.wav : Will be covering that and giving you some pics we're good at it.
# audio-chunks/chunk722.wav : That all said you have a great evening drive carefully.
# audio-chunks/chunk723.wav : When you get home do like we do it's quite simple make sure you hug your family really make sure you hug your children they will feel better you will feel better.
# audio-chunks/chunk724.wav : We'll have a big webcast tonight.
# audio-chunks/chunk725.wav : On the semiconductors you can check it out at convictionleaders.com if you'd like.
# audio-chunks/chunk726.wav : Until tomorrow peace out all thanks for joining us.
# audio-chunks/chunk727.wav : Good night.
# audio-chunks/chunk728.wav : Bye-bye.
# audio-chunks/chunk729.wav : This has been investors edge with gary kaltbaum on biz talk to listen to past episodes or to get in contact with gary go to garykay.com that's gary kay.com.
#
# Full text: At fred meyer we want our fresh produce to meet your expectations which is why we're dedicated to doing up to a 27 point inspection on our fruits and veggies checking for things like scarring in fact only the best produce like zesty oranges and crisp carrots reach our shelves because when it comes to fresh our higher standards mean pressure produce fred meyer fresh for everyone. Investor's edge with gary kaltbaum straight talk about you and your money now from the best talk studios here is gary kaltbaum. And work once again to investors edge on gary culp i'm your host a thanks for being with us today glad you here ladies and gentlemen happy that you are listening. It's april 10th. 2023 it is monday. And let me just start off by saying. At the end of each show. We do a little. Go home hug your family. Hug your children. They will feel better. That you will feel better. We started saying go home and hug your children. The day of the columbine incident. Columbine incident the columbine murders. I i. How many years ago was that hold on columbine. April 20th 1999. For almost. 4 years. I have been ending the show. The same way. I don't want to get into why and it has nothing to do with my family. But. Hint. As often as you can. As often as you want. Make sure your family and your kids. Know how you feel about. Has nothing to do i'm not mentioning it because of my family. Just. I'm mentioning it because of. A families that i know. Okay. Right out of the box. And since we mentioned 1999. Oh that was the year that the bubble. Of a. Set the stage for the worst bear market. I think in history for the nasdaq that dropped 80% nasdaq 180%. I out in 1999. And since then. We have stated to you. Oh several thousand times. When all is said and done. Watch the semic. We're getting right into the crux of something here ladies. This is what i've been saying to you. Forever. Since 2000. I would suggest to you. That 90 some odd percent of the time. It's not a hundred. Watch the semic. They have been amazing. Leaders to the upside. And leaders to the down. And what i mean by that is. Kind of simple. You can't have a real bull market. Without the sem. Now it used to be. Financials. And then it went to financials. And semiconductors. After 08. We were able to back out. The financials. Because during 08. 0708. The market rallied without them. And then of course. They let the crash. In a way. One of our best calls in history. Was it '07 that whole year. We would just say to you something was wrong with the financial. When the market i remember the down rally the thousand points. And the financials couldn't bu. The big financials. With the dow rally 1,000 points. And then when the dow came in a thousand. They let down and let down badly. And then when the market would rally up a little bit. They were hesitant. So they had this. They lost the leadership quality. But they showed us the way. I'm a little did we have no idea. That disaster lied ahead. We had no idea. Merrill. Bear ste. Countrywide financial wachov. Who else went out. Back. We have no idea. You know who did have an idea. The market. But since. It's pretty much the semis. And when we say lead. Very simply. They hold up best. In good markets and corrections. When they crack. It will be indicative. Of the rest of the market. The eventuality. Of the rest of the market. And you don't have to believe me. If you have some stock software. That you can just go back my softwares allows me to go back. Daily weekly and monthly. To the beginning of time. I can change the date. And all i can tell you as i have done this study. I don't think the word is uncann. I just think. How it is. And and why would that be. Well semiconductor chips. Everything. Almost everything. And they have basically moved the needle. And why am i bringing them up today what what matters so much today. Well this morning. Very simply. Nasdaq was getting smacked around. And as you know the nasdaq's pretty important. To the m ...
